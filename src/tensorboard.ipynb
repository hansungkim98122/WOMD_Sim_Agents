# %%
    # %load_ext tensorboard

    # %tensorboard --logdir tb_logs
# Out:
# Reusing TensorBoard on port 6006 (pid 288308), started 8 days, 12:09:55 ago. (Use '!kill 288308' to kill it.)
#       <iframe id="tensorboard-frame-a3a1c6880895879c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a3a1c6880895879c");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard

# %tensorboard --logdir tb_logs/smart_rl --port 6007
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 1738327), started 1:57:02 ago. (Use '!kill 1738327' to kill it.)
#       <iframe id="tensorboard-frame-7849556e72220649" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7849556e72220649");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
